# %%
import random
import pandas as pd
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data
# Out:
#    whoAmI
# 0   robot
# 1   human
# 2   human
# 3   robot
# 4   robot
# 5   human
# 6   robot
# 7   human
# 8   human
# 9   robot
# 10  robot
# 11  robot
# 12  human
# 13  human
# 14  robot
# 15  robot
# 16  robot
# 17  human
# 18  human
# 19  human

# %%
import random
import pandas as pd
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
pd.get_dummies(data)
# Out:
#     whoAmI_human  whoAmI_robot
# 0              1             0
# 1              0             1
# 2              0             1
# 3              0             1
# 4              0             1
# 5              0             1
# 6              0             1
# 7              1             0
# 8              1             0
# 9              1             0
# 10             1             0
# 11             0             1
# 12             1             0
# 13             0             1
# 14             0             1
# 15             1             0
# 16             1             0
# 17             0             1
# 18             1             0
# 19             1             0

# %%
import pandas as pd
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)

data = pd.DataFrame({'whoAmI':lst})
print(data)

def FirstCol(list):
  for i in range(0,len(list)):
    if list[i] == "human":
      list[i] = 1
    else:
      list[i] = 0

  print(pd.DataFrame({'whoAmI_human?':list}))
def SecondCol(list):
  for i in range(0,len(list)):
    if list[i] == 1:
      list[i] = 0
    else:
      list[i] = 0

  print(pd.DataFrame({'whoAmI_robot?':list}))
FirstCol(lst)
SecondCol(lst)
# Out:
#    whoAmI
# 0   human
# 1   robot
# 2   robot
# 3   human
# 4   human
# 5   robot
# 6   human
# 7   robot
# 8   robot
# 9   robot
# 10  human
# 11  human
# 12  human
# 13  human
# 14  robot
# 15  robot
# 16  robot
# 17  robot
# 18  human
# 19  human
#     whoAmI_human?
# 0               1
# 1               0
# 2               0
# 3               1
# 4               1
# 5               0
# 6               1
# 7               0
# 8               0
# 9               0
# 10              1
# 11              1
# 12              1
# 13              1
# 14              0
# 15              0
# 16              0
# 17              0
# 18              1
# 19              1
#     whoAmI_robot?
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0
# 5               1
# 6               0
# 7               1
# 8               1
# 9               1
# 10              0
# 11              0
# 12              0
# 13              0
# 14              1
# 15              1
# 16              1
# 17              1
# 18              0
# 19              0
